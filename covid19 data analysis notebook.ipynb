# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
#  ### Importing covid19 dataset

# %%
covid_dataset = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
covid_dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# ####  the shape of the dataframe

# %%
covid_dataset.shape
# Out:
# (266, 104)

# %% [markdown]
# ###  Deleteing the useless columns

# %%
covid_dataset.drop(["Lat","Long"],inplace=True,axis=1)
covid_dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# ###  Aggregating the rows by the country
#
# To get rid of Province/State column

# %%
covid_dataset_aggregated = covid_dataset.groupby("Country/Region").sum()
covid_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %% [markdown]
# ### Visualizing the number of infections in the first 4 months of 2020
#
# Comparing between Spain , China , Italy

# %%
covid_dataset_aggregated.loc['China'].plot()
covid_dataset_aggregated.loc['Italy'].plot()
covid_dataset_aggregated.loc['Spain'].plot()
plt.xlabel("Date")
plt.ylabel("Number of infections")

plt.legend()

# %% [markdown]
# ###  Caculating the first derivative of the curve

# %%
covid_dataset_aggregated.loc['China'].diff().plot()
plt.xlabel("Date")
plt.ylabel("Number of infections")
# Out:
# Text(0, 0.5, 'Number of infections')

# %% [markdown]
# ###  Maxmimum infection rate for China

# %%
covid_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %% [markdown]
# ### Visualizing the number of infection in all over the world per month

# %%
Jan = covid_dataset_aggregated.loc[:,'1/31/20'].sum()
Feb = covid_dataset_aggregated.loc[:,'2/29/20'].sum()
March = covid_dataset_aggregated.loc[:,'3/31/20'].sum()
April = covid_dataset_aggregated.loc[:,'4/30/20'].sum()

months = ['Jan','Feb','March','April']
infection_values=[Jan,Feb,March,April]

plt.bar(x=months,height=infection_values)
plt.title("Total Infections(per millions) in the world per month")
plt.xlabel("Month")
plt.ylabel("Number of infections per millions")

plt.show()

# %% [markdown]
# ###  Finding maximum infection rate for all of the countries.

# %%
countries_names = list(covid_dataset_aggregated.index)
max_infec = []

for country in countries_names:
    max_infec.append(covid_dataset_aggregated.loc[country].diff().max())

covid_dataset_aggregated["max_infections_rate"] = max_infec

# %%
from matplotlib.pyplot import figure
import random


covid_dataset_aggregated = pd.DataFrame(covid_dataset_aggregated['max_infections_rate'])
max_infec = list(covid_dataset_aggregated['max_infections_rate'])
countries = list(covid_dataset_aggregated.index)

res = {countries[i]: max_infec[i] for i in range(len(countries))}

random_countries = list(random.sample(countries,20))
random_countries_infec=[]

for c in random_countries:
    random_countries_infec.append(res[c])
figure(num=None, figsize=(10,10), dpi=256, facecolor='w', edgecolor='r')
plt.title("Max Infections Rate ")
plt.xlabel("Maximum Number of infextions in the first 4 months of 2020")
plt.ylabel("20 random Countries")
sns.barplot(x=random_countries_infec,y=random_countries)
plt.show()

# %% [markdown]
# ###  Importing the world happiness report dataset

# %%
world_happiness_dataset = pd.read_csv('Datasets/worldwide_happiness_report.csv')
world_happiness_dataset.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ###  Dropping the useless columns

# %%
useless_columns = ['Overall rank','Score','Generosity','Perceptions of corruption']

world_happiness_dataset.drop(useless_columns,inplace=True,axis=1)

world_happiness_dataset.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
covid_dataset_aggregated.head()
# Out:
#                 max_infections_rate
# Country/Region
# Afghanistan                   232.0
# Albania                        34.0
# Algeria                       199.0
# Andorra                        43.0
# Angola                          5.0

# %%
world_happiness_dataset.set_index('Country or region',inplace=True)
world_happiness_dataset.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### Joining the two data set together on the Country Column

# %%
data = covid_dataset_aggregated.join(world_happiness_dataset,how='inner')

data.head()
# Out:
#              max_infections_rate  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ###  Correlation matrix

# %%
data.corr()
# Out:
#                               max_infections_rate  GDP per capita  \
# max_infections_rate                      1.000000        0.250118
# GDP per capita                           0.250118        1.000000
# Social support                           0.191958        0.759468
# Healthy life expectancy                  0.289263        0.863062
# Freedom to make life choices             0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infections_rate                 0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infections_rate                               0.078196
# ...

# %% [markdown]
# ##  Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %% [markdown]
# ###  Plotting GDP vs maximum Infection rate

# %%
x = data['GDP per capita']
y = data['max_infections_rate']

sns.regplot(x=x,y=np.log(y))
# Out:
# <AxesSubplot: xlabel='GDP per capita', ylabel='max_infections_rate'>

# %% [markdown]
# ###  Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max_infections_rate']

sns.regplot(x=x,y=np.log(y))
# Out:
# <AxesSubplot: xlabel='Social support', ylabel='max_infections_rate'>

# %% [markdown]
# ###  Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max_infections_rate']

sns.regplot(x=x,y=np.log(y))
# Out:
# <AxesSubplot: xlabel='Healthy life expectancy', ylabel='max_infections_rate'>

# %% [markdown]
# ###  Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max_infections_rate']

sns.regplot(x=x,y=np.log(y))
# Out:
# <AxesSubplot: xlabel='Freedom to make life choices', ylabel='max_infections_rate'>
